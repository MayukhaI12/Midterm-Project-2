# %% [markdown]
# <a href="https://colab.research.google.com/github/MayukhaI12/Midterm-Project-2/blob/main/Mid_Term_Project%5B2%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Mount github repo to the colab:
# !git clone https://github.com/sjasthi/python_input_files.git
# Out:
# fatal: destination path 'python_input_files' already exists and is not an empty directory.

# %%
#@title We can also get the file directly using 'wget' (web get):
# Make sure that you are using the link to the RAW file
# !wget https://raw.githubusercontent.com/sjasthi/python_input_files/main/gasprices.txt
# Out:
# --2023-03-15 00:54:55--  https://raw.githubusercontent.com/sjasthi/python_input_files/main/gasprices.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19059 (19K) [text/plain]
# Saving to: ‘gasprices.txt.2’
#
# gasprices.txt.2     100%[===================>]  18.61K  --.-KB/s    in 0.001s
#
# 2023-03-15 00:54:55 (15.3 MB/s) - ‘gasprices.txt.2’ saved [19059/19059]

# %% [markdown]
# #Option 1 (Design: We are storing the data as LIST of Lists)
#
# What do we call this big list?
# - x is bad name
# - file_data - is too generic
# - prices_master_list -- we can go with this
#
# What do we call the values inside this prices_master_list?
# - y is bad name
# - line_data - is too generic
# - price_mini_list - we can go with this
#
# What do we call indiviual values within the price_mini_list?
# - month
# - date
# - year
# - price

# %%
#@title Method contracts for the final solution:-

'''
def read_gas_prices()
def get_average_price_per_year()
def get_average_price_per_month()
def get_highest_and_lowest_prices_per_year()
def generate_list_of_prices_lowest_to_highest()
def generate_list_of_prices_highest_to_lowest()

'''

# %%
#@title List all the global variables here:-

# prices_master_list captures all the gas prices data from the file as "list of lists"

gasprices = open("/content/gasprices.txt")

prices_master_list = []

for i in gasprices:
  prices_mini_list = i.rstrip()
  prices_mini_list = i.rsplit("-")
  prices_mini_list.append(prices_mini_list[-1].rsplit(":")[0])
  prices_mini_list.append(prices_mini_list[-2].rsplit(":")[1])
  prices_mini_list[-1] = prices_mini_list[-1].rstrip()
  prices_mini_list.pop(2)
  prices_master_list.append(prices_mini_list)

# %%
#@title read_gas_prices()
'''
Method Name: read_gas_prices
Input: file name
Returns: None
What global variables are updated? prices_master_list

This function takes in a gas prices file name and creates a prices_master_list
'''

def read_gas_prices(file_name = 'gasprices.txt'):

  print("Printing: prices_master_list:-")
  print("------------------------------")
  print()

  for i in prices_master_list:
    print(i)
    pass

read_gas_prices('gasprices.txt')
# Out:
# Printing: prices_master_list:-
# ------------------------------
#
# ['04', '05', '1993', '1.068']
# ['04', '12', '1993', '1.079']
# ['04', '19', '1993', '1.079']
# ['04', '26', '1993', '1.086']
# ['05', '03', '1993', '1.086']
# ['05', '10', '1993', '1.097']
# ['05', '17', '1993', '1.106']
# ['05', '24', '1993', '1.106']
# ['05', '31', '1993', '1.107']
# ['06', '07', '1993', '1.104']
# ['06', '14', '1993', '1.101']
# ['06', '21', '1993', '1.095']
# ['06', '28', '1993', '1.089']
# ['07', '05', '1993', '1.086']
# ['07', '12', '1993', '1.081']
# ['07', '19', '1993', '1.075']
# ['07', '26', '1993', '1.069']
# ['08', '02', '1993', '1.062']
# ['08', '09', '1993', '1.06']
# ['08', '16', '1993', '1.059']
# ['08', '23', '1993', '1.065']
# ['08', '30', '1993', '1.062']
# ['09', '06', '1993', '1.055']
# ['09', '13', '1993', '1.051']
# ['09', '20', '1993', '1.045']
# ['09', '27', '1993', '1.047']
# ['10', '04', '1993', '1.092']
# ['10', '11', '1993', '1.09']
# ['10', '18', '1993', '1.093']
# ...

# %%
#@title  get_average_price_per_year()

'''
Method Name: get_average_price_per_year
Input: None (it relies on the global variable prices_master_list)
Returns: None
What global variables are updated? None
Displays:

Year      Average Price
1993     1.07
1994     1.09
'''

def get_average_price_per_year():
  
  pass

ct = 0

sum = 0

avg = []

j = prices_master_list[0][2]

print(j)
for i in prices_master_list:
  if(i[2] == j):
    ct = ct + 1
    sum = sum + float(i[3])
    j = i[2]
  else:
    avg.append([j, sum/ct])
    ct = 0
    sum = 0
    j = i[2]

print("Displaying average price per month:")
print("-----------------------------------")

print("Year ------ Average price")
print()
for i in avg:
  print(i[0], "------", i[-1])
# Out:
# 1993
# Displaying average price per month:
# -----------------------------------
# Year ------ Average price
#
# 1993 ------ 1.0711538461538466
# 1994 ------ 1.079549019607843
# 1995 ------ 1.158313725490196
# 1996 ------ 1.2467499999999998
# 1997 ------ 1.243705882352941
# 1998 ------ 1.0702156862745098
# 1999 ------ 1.1799607843137256
# 2000 ------ 1.526862745098039
# 2001 ------ 1.4605769230769232
# 2002 ------ 1.390549019607843
# 2003 ------ 1.6052941176470592
# 2004 ------ 1.9014117647058826
# 2005 ------ 2.324078431372549
# 2006 ------ 2.6248823529411767
# 2007 ------ 2.8523461538461543
# 2008 ------ 3.301647058823529
# 2009 ------ 2.4189411764705886
# 2010 ------ 2.8373529411764715
# 2011 ------ 3.5852941176470594
# 2012 ------ 3.6858269230769234

# %%
#@title get_average_price_per_month()

def get_average_price_per_month():
  ct = 0

  sum = 0

  avg_mnth = []

  mnth = prices_master_list[0][0] + "-" + prices_master_list[0][2]

  for i in prices_master_list:
    curr_mnth = i[0] + "-" + i[2]
    if(curr_mnth == mnth):
      ct = ct + 1
      sum = sum + float(i[3])
      mnth = curr_mnth
    else:
      avg_mnth.append([mnth,sum/ct])
      ct = 0
      sum = 0
      mnth = curr_mnth

  print("Displaying average price per month:")
  print("-----------------------------------")

  print("Month - Year ------ Average price")
  print()
  for i in avg_mnth:
    print(i[0], "------", i[-1])

    pass

get_average_price_per_month()
# Out:
# Displaying average price per month:
# -----------------------------------
# Month - Year ------ Average price
#
# 04-1993 ------ 1.078
# 05-1993 ------ 1.104
# 06-1993 ------ 1.095
# 07-1993 ------ 1.075
# 08-1993 ------ 1.0614999999999999
# 09-1993 ------ 1.0476666666666665
# 10-1993 ------ 1.0916666666666666
# 11-1993 ------ 1.062
# 12-1993 ------ 1.0066666666666666
# 01-1994 ------ 1.0
# 02-1994 ------ 1.0096666666666667
# 03-1994 ------ 1.0079999999999998
# 04-1994 ------ 1.0326666666666666
# 05-1994 ------ 1.04925
# 06-1994 ------ 1.0823333333333334
# 07-1994 ------ 1.1086666666666665
# 08-1994 ------ 1.161
# 09-1994 ------ 1.1396666666666666
# 10-1994 ------ 1.112
# 11-1994 ------ 1.1173333333333335
# 12-1994 ------ 1.13
# 01-1995 ------ 1.13075
# 02-1995 ------ 1.119
# 03-1995 ------ 1.1170000000000002
# 04-1995 ------ 1.1653333333333336
# 05-1995 ------ 1.233
# 06-1995 ------ 1.236
# 07-1995 ------ 1.1955
# 08-1995 ------ 1.1686666666666667
# 09-1995 ------ 1.157
# ...

# %%
#@title get_highest_and_lowest_prices_per_year()

def get_highest_and_lowest_prices_per_year():

  list_of_years = []
  list_of_prices = []

  list_of_highest_prices = {}
  list_of_lowest_prices = {}

  x = []
  y = []

  for i in prices_master_list:
    i[-1] = float(i[-1])
    if (i[-2] not in list_of_years):
      list_of_years.append(i[-2])
    elif (i[-2] in list_of_years):
      continue

  for i in prices_master_list:
    if (i[2] == list_of_years[0]):
      list_of_prices.append(i[-1])
      list_of_highest_prices.update({ i[-2] : max(list_of_prices)})

      list_of_lowest_prices.update({ i[-2] : min(list_of_prices)})

      list_of_prices.clear()
      list_of_years.pop(0)
      list_of_years.append(i[2])


  print("Displaying the highest price per year:")
  print()

  for a in list_of_highest_prices:
    print("Highest price for the year", a, ":", list_of_highest_prices[a])

  print()
  print("---------------------------------")
  print()

  print("Displaying the lowest price per year:")
  print()

  for a in list_of_lowest_prices:
    print("Lowest price for the year", a, ":", list_of_lowest_prices[a])

    pass

get_highest_and_lowest_prices_per_year()
# Out:
# Displaying the highest price per year:
#
# Highest price for the year 1993 : 1.068
# Highest price for the year 1994 : 0.992
# Highest price for the year 1995 : 1.127
# Highest price for the year 1996 : 1.129
# Highest price for the year 1997 : 1.272
# Highest price for the year 1998 : 1.148
# Highest price for the year 1999 : 0.977
# Highest price for the year 2000 : 1.312
# Highest price for the year 2001 : 1.446
# Highest price for the year 2002 : 1.152
# Highest price for the year 2003 : 1.487
# Highest price for the year 2004 : 1.552
# Highest price for the year 2005 : 1.824
# Highest price for the year 2006 : 2.281
# Highest price for the year 2007 : 2.382
# Highest price for the year 2008 : 3.159
# Highest price for the year 2009 : 1.737
# Highest price for the year 2010 : 2.718
# Highest price for the year 2011 : 3.124
# Highest price for the year 2012 : 3.358
# Highest price for the year 2013 : 3.373
#
# ---------------------------------
#
# ...

# %%
#@title generate_list_of_prices_lowest_to_highest()

def generate_list_of_prices_lowest_to_highest():

  list_of_prices_lowest_to_highest = []

  for i in prices_master_list:
    i[-1] = float(i[-1])
    list_of_prices_lowest_to_highest.append(i[-1])

  list_of_prices_lowest_to_highest.sort()

  print("List of prices from lowest to highest:")
  print("--------------------------------------")

  print(list_of_prices_lowest_to_highest)

  pass

generate_list_of_prices_lowest_to_highest()
# Out:
# List of prices from lowest to highest:
# --------------------------------------
# ...

# %%
#@title generate_list_of_prices_highest_to_lowest()

def generate_list_of_prices_highest_to_lowest():

  list_of_prices_highest_to_lowest = []

  for i in prices_master_list:
    i[-1] = float(i[-1])
    list_of_prices_highest_to_lowest.append(i[-1])

  list_of_prices_highest_to_lowest.sort()

  list_of_prices_highest_to_lowest.reverse()

  print("List of prices from highest to lowest:")
  print("--------------------------------------")

  print(list_of_prices_highest_to_lowest)

  pass

generate_list_of_prices_highest_to_lowest()
# Out:
# List of prices from highest to lowest:
# --------------------------------------
# ...

# %%
#@title display_execution_times()

'''
Function Name												          Time Taken
def read_gas_prices() 									        	0.004
def get_average_price_per_year()							    0.008
def get_average_price_per_month()
def get_highest_and_lowest_prices_per_year()
def generate_list_of_prices_lowest_to_highest()
def generate_list_of_prices_highest_to_lowest()
									            Total Time					4.000
'''

def display_execution_times():

	import time

	start_time = time.time()  
	read_gas_prices() 	
	end_time = time.time()  
	run_time_for_read_gas_prices = end_time - start_time
 
	start_time = time.time()  
	get_average_price_per_year()
	end_time = time.time()  
	run_time_for_get_average_price_per_year = end_time - start_time

	start_time = time.time()  
	get_average_price_per_month()
	end_time = time.time()  
	run_time_for_get_average_price_per_month = end_time - start_time

	start_time = time.time()  
	get_highest_and_lowest_prices_per_year()
	end_time = time.time()  
	run_time_for_get_highest_and_lowest_prices_per_year = end_time - start_time
 
	start_time = time.time()  
	generate_list_of_prices_lowest_to_highest()
	end_time = time.time()  
	run_time_for_generate_list_of_prices_lowest_to_highest = end_time - start_time

	start_time = time.time()  
	generate_list_of_prices_highest_to_lowest()
	end_time = time.time()  
	run_time_for_generate_list_of_prices_highest_to_lowest = end_time - start_time

	print()
	print("-------------------------------------------------------------------------------------")
	print("-------------------------------------------------------------------------------------")

	print()
	print('read_gas_prices() runtime : ', run_time_for_read_gas_prices)
	print()
	print('get_average_price_per_year() runtime : ', run_time_for_get_average_price_per_year)
	print()
	print('get_average_price_per_month() runtime : ', run_time_for_get_average_price_per_month)
	print()
	print('get_highest_and_lowest_prices_per_year() runtime : ', run_time_for_get_highest_and_lowest_prices_per_year)
	print()
	print('get_average_price_per_year() runtime : ', run_time_for_generate_list_of_prices_lowest_to_highest)
	print()
	print('get_average_price_per_year() runtime : ', run_time_for_generate_list_of_prices_highest_to_lowest)
	print()

display_execution_times()
# Out:
# Printing: prices_master_list:-
# ------------------------------
#
# ['04', '05', '1993', 1.068]
# ['04', '12', '1993', 1.079]
# ['04', '19', '1993', 1.079]
# ['04', '26', '1993', 1.086]
# ['05', '03', '1993', 1.086]
# ['05', '10', '1993', 1.097]
# ['05', '17', '1993', 1.106]
# ['05', '24', '1993', 1.106]
# ['05', '31', '1993', 1.107]
# ['06', '07', '1993', 1.104]
# ['06', '14', '1993', 1.101]
# ['06', '21', '1993', 1.095]
# ['06', '28', '1993', 1.089]
# ['07', '05', '1993', 1.086]
# ['07', '12', '1993', 1.081]
# ['07', '19', '1993', 1.075]
# ['07', '26', '1993', 1.069]
# ['08', '02', '1993', 1.062]
# ['08', '09', '1993', 1.06]
# ['08', '16', '1993', 1.059]
# ['08', '23', '1993', 1.065]
# ['08', '30', '1993', 1.062]
# ['09', '06', '1993', 1.055]
# ['09', '13', '1993', 1.051]
# ['09', '20', '1993', 1.045]
# ['09', '27', '1993', 1.047]
# ['10', '04', '1993', 1.092]
# ['10', '11', '1993', 1.09]
# ['10', '18', '1993', 1.093]
# ['10', '25', '1993', 1.092]
# ['11', '01', '1993', 1.084]
# ...
